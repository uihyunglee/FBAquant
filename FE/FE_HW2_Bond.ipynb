# %% [markdown]
# # FE Homework 2
# **FBA Quant 이의형**

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def rabbit_stair(n):
    if (n == 1) or (n == 2):
        return n
    elif n == 3:
        return 4
    else:
        return rabbit_stair(n - 3) + rabbit_stair(n - 2) + rabbit_stair(n - 1)

stairs = 5

print(f'계단이 {stairs}칸일 때, {rabbit_stair(stairs)}만큼의 경우의 수가 존재한다.')
# Out:
# 계단이 5칸일 때, 13만큼의 경우의 수가 존재한다.

# %% [markdown]
# ---
